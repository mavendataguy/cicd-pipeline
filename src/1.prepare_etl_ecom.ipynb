# %%
# %sql 
--DROP DATABASE IF EXISTS ecom_growth CASCADE;
CREATE DATABASE IF NOT EXISTS ecom_growth
LOCATION "/mnt/mavendataguy/output/ecom_growth";
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql 
DROP TABLE IF EXISTS ecom_growth.products;
CREATE TABLE IF NOT EXISTS ecom_growth.products
(      product_id int, 
       created_at date, 
      product_name varchar(100),
      ingestion_date date
) USING DELTA
LOCATION "/mnt/mavendataguy/output/ecom_growth/products";
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql 
DROP DATABASE IF EXISTS ecom_growth_presentation CASCADE;

CREATE DATABASE IF NOT EXISTS ecom_growth_presentation 

LOCATION "/mnt/mavendataguy/output/presentation/ecom_growth";
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>
